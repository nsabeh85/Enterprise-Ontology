# %%
import sys
sys.path.append('../src')
from telemetry_logger import TelemetryLogger
import json

logger = TelemetryLogger()

# %%
# Use correct path from notebooks folder
logger = TelemetryLogger(storage_path='../outputs/telemetry_logs.jsonl')

# %%
logs = logger.read_logs()
print(f"Total queries logged: {len(logs)}")
# Out:
# Total queries logged: 1

# %%
print(f"\nFirst log entry:")
print(json.dumps(logs[0], indent=2))
# Out:
# First log entry:
# {
#   "query_id": "query_20251120_181221_ca484ac6",
#   "user_id_hash": "5196da40749b5940",
#   "timestamp": "2025-11-20T18:12:21.863538+00:00",
#   "original_query": "Is SF available at DFW10?",
#   "expanded_terms": [
#     {
#       "term": "ServiceFabric",
#       "weight": 1.0,
#       "source": "matched_synonym"
#     }
#   ],
#   "matched_entities": [
#     "ServiceFabric",
#     "DFW10"
#   ],
#   "disambiguation_context": {},
#   "query_rewrite_time_ms": 8.5,
#   "retrieval_time_ms": null,
#   "generation_time_ms": null,
#   "total_pipeline_time_ms": null,
#   "retrieval_results": [],
#   "rerank_results": [],
#   "first_answer_success": null,
#   "user_feedback": null,
#   "metadata": {
#     "session_id": "session_abc",
#     "source": "web_chat"
#   }
# }
