# %%
import os
import sys

# Add src directory to Python path
sys.path.append('../src')

# Get the full path to the ontology runtime JSON
ontology_path = os.path.abspath('../data/ontology_runtime.json')

# Now try importing
from disambiguation_rules import Disambiguator

# Create disambiguator instance with full path
disambiguator = Disambiguator(ontology_path=ontology_path)

# Test queries
test_queries = [
        "What's the fabric topology at DFW10?"],

# Test disambiguation
for query in test_queries:
    context = disambiguator.get_disambiguation_context(query)
    print(f"\nQuery: {query}")
    print(f"Normalized Query: {disambiguator.normalize_query(query)}")
    print(f"Disambiguation Context: {context}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 22
#      20 # Test disambiguation
#      21 for query in test_queries:
# ---> 22     context = disambiguator.get_disambiguation_context(query)
#      23     print(f"\nQuery: {query}")
#      24     print(f"Normalized Query: {disambiguator.normalize_query(query)}")
#
# File ~/ontonomy 2 /notebooks/../src/disambiguation_rules.py:78, in get_disambiguation_context(self, query)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/ontonomy 2 /notebooks/../src/disambiguation_rules.py:13, in normalize_query(self, query)
#      10     script_dir = os.path.dirname(os.path.abspath(__file__))
#      11     ontology_path = os.path.join(script_dir, '..', 'data', 'ontology_runtime.json')
# ---> 13 # Print the path to verify
#      14 print(f"Loading ontology from: {ontology_path}")
# ...
